# %%
print("hola mundo")

# %% [markdown]
# <h1>Primer programa<h1>

# %%
print("Primeramente podemos ver que no necesitamos declar variables")
numero1=int(input("ingresa numero uno "))
numero2=int(input("ingresa numero dos "))
suma=numero1+numero2
print(f"la suma es: {suma}")

# %%
print("Tambien puedes cambiar el valor de las variables muy drasticamente")
suma="Este es un cambio drastico"
print(f"ahora ya no es un numero, ahora es un texto: {suma}")

# %%
print("Sacar promedio")
calf1=float(input("ingresa calificacion "))
calf2=float(input("ingresa calificacion "))
calf3=float(input("ingresa calificacion "))
calf4=float(input("ingresa calificacion "))
calf5=float(input("ingresa calificacion "))
calf6=float(input("ingresa calificacion "))
calf7=float(input("ingresa calificacion "))
calf8=float(input("ingresa calificacion "))
calf9=float(input("ingresa calificacion "))
calf10=float(input("ingresa calificacion "))
promedio=(calf1+calf2+calf3+calf4+calf5+calf6+calf7+calf8+calf9+calf10)/10
print(f"Tu promedio es: {promedio}")
