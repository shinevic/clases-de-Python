# %% [markdown]
# **DICCIONARIO**

# %%
my_dict = dict()
other_dict = {}
print(type(my_dict))
print(type(other_dict))

# %%
persona = {
    'name': 'Victor',
    'lastname': 'Villa',
    'age': 22,
    'skills': ['javascript', 'react', 'python', 'switf'],
    'address': {
        'street': 'El ticui',
        'telefono': 12345678763
    }

}
print(persona)

# %% [markdown]
# **CALCULAR LONGITUD**

# %%
print(len(persona))

# %% [markdown]
# **ACCEDER A LOS ELEMENTOS**

# %%
print(persona['name'])
print(type(persona['name']))

print(persona['lastname'])
print(type(persona['lastname']))

print(persona['skills'])
print(type(persona['skills']))

print(persona['address'])
print(type(persona['address']))

# %%
print(persona.get('country'))
print(persona.get('skills'))

# %% [markdown]
# **MODIFICAR DATOS**

# %%
print(persona)
persona['last_name'] = 'Garcia'
print(persona)

# %% [markdown]
# **AGREGAR NUEVOS CAMPOS**

# %%
print(persona)
persona['last_name'] = 'Garcia'
print(persona)

# %% [markdown]
# **VERIFICAR LLAVES**

# %%
print('name' in persona)
print('marital_status' in persona)

# %% [markdown]
# **ANALIZAR TODAS LAS LLAVES EXISTENTES**

# %%
print(persona.keys())

# %% [markdown]
# **ANALIZAR TODOS LOS VALORES EXISTENTES**

# %%
print(persona.values())
