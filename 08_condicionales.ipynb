# %% [markdown]
# **CONDICIONAL IF**

# %%
#Sintaxis
if condition:
  aqui pones lo que ocurre si se cumple
else:
  aqui pones lo que ocurre si no se cumple

# %%
numero=int(input("ingrese un numero "))

if numero < 0:
  print('El numero es negativo')
else: 
   print('El numero es positivo')

# %% [markdown]
# **IF ELIF ELSE**

# %%
numero = int(input("Ingrese un numero "))
if numero < 0:
  print('el numero es negativo')
elif numero > 0:
  print('el numero es positivo')
else:
  print('el numero es 0')

# %% [markdown]
# **ANIDACION**

# %%
numero = int(input("Ingrese un numero "))
if numero > 0:
  if numero % 2 == 0:
    print('el numero es positivo y par')
  else:
    print('el numero es positivo e impar')

elif numero == 0:
 print('el numero es cero')

else: 
  print('el numero es negativo')

# %% [markdown]
# **CONDICIONALES Y OPERADORES LOGICOS**

# %%
numero =int(input("Ingresa un numero "))
if numero > 0 and numero % 2 == 0: 
  print('El numero es entero y par')

elif numero > 0 and numero % 2 != 0:
  print('El numeroe es positivo e impar')

elif numero == 0:
  print('El numero es cero')

else:
  print('El numero es negativo')

# %%
user = 'Vicman'
access_level = 4
if user == 'admin' or access_level >= 4:
  print('¡acceso concedido!')
else:
  print('¡acceso denagado!')
