# %%
def adicion():
  a = 2
  b = 3
  total = a + b

# %%
adicion()

# %%
def function_name():
  code
  code

# %% [markdown]
# **RETORNAR VALORES DE UNA FUNCION**

# %%
def adicion():
a = 2
b = 3
total = a + b
total = a + b
return total

# %%
print(adicion())

# %% [markdown]
# **FUNCIONES CON PARAMETROS**

# %%
def adicion (a,b):
  total = a+b
  return total

# %%
print(adicion(1,2))

# %% [markdown]
# **ARGUMENTOS DE TIPO KEY:VALUE**

# %%
def person_info(name, lastname, career):
  print(f'hola {name} {lastname}, Gracias por escoger la carrera de {career}')

# %%
print(person_info(name='Victor', lastname='Villa', career='Sistemas'))

# %% [markdown]
# **TIPOS DE VALORES A RETORNAR**

# %%
def name(name):
  return name 

  name('Victor')

# %%
#Booleanos
def is_pair(n):
  if n%2 == 0:
    return True
    return False

  print(is_pair(8))
  print(is_pair(5))

# %%
#Listas
def find_pair(n):
  pairs = []
  for i in range(n+1):
    if i%2 == 0:
      pairs.append(i)
    return pairs

   print(find_pair(10))
